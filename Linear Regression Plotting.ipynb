# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def datamarker(N = 100, err = 1.0):
    x = np.linspace(-1,1,N)
    y = 2*x-3
    y = y + err*np.random.randn(N)
    return x,y

# %%
X_train, y_train = datamarker(500,0.2)
X_train = X_train[:,np.newaxis]
plt.scatter(X_train,y_train)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train, )
# Out:
# LinearRegression()

# %%
plt.scatter(X_train, y_train)
plt.plot(X_train, model.predict(X_train), color = 'Red')
plt.title('Training Performance')
# Out:
# Text(0.5, 1.0, 'Training Performance')

# %%
# Here, testing of the data is done
X_test, y_test = datamarker(50,0.2)
X_test = X_test[:,np.newaxis]

# %%
plt.scatter(X_test,y_test)
plt.plot(X_test, model.predict(X_test), color = 'Red')
plt.title('Testing Performance')
# Out:
# Text(0.5, 1.0, 'Testing Performance')
